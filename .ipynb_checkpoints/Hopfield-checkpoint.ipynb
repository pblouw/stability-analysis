# %% [markdown]
# # Stability Analysis of a Hopfield Network
# This notebook analyzes the behavior of a simple hopfield network that is designed to produce an attractor for each of five unique patterns. The patterns are randomly generated HRR's, the network weights are generated by summing the outer products of each HRR with itself, and the network non-linearity is the hyperbolic tangent function (np.tanh). This non-linearity is chosen because it allows the network nodes to take on negative values, which is necessary to obtain states that correspond to HRR's (whose elements are randomly distributed with a mean of zero).

# %%
import copy
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy import integrate

# Main parameters: HRR dimensionality, dt, and total simulation time
np.random.seed(89)

D = 128
dt = 0.001
t = 5

# Function definitions
def disturb(v, std):
    # Add mean-zero gaussian noise to a vector
    return v + np.random.normal(loc=0, scale=std, size=len(v)) 

def norm_of_vector(v):
    return np.linalg.norm(v)

def normalize(v):
    return v / norm_of_vector(v)

def integral(a, dx=0.0001):
    # Compute the integral of arctanh from 0 to x=a (for calculating unit harmony)
    return integrate.quad(np.arctanh, 0.0, a)

def update(a, w):
    # Update the state of the hopfield network
    k = 25
    dH = np.tanh(np.dot(w, a)) - a # From Smolensky and Legendre 
    a += k * dt * dH  # Update rule
    a += dt * bias # Add bias
    a = np.clip(a, a_min=-0.999, a_max=0.999) # Clip values to stay within range of tanh function
    return a 

def harmony_eval(a, weights):
    # Evaluate the wellformedness of a state with respect to the network weights
    H_c = np.dot(np.transpose(a), np.dot(weights, a)) # Core Harmony
    H_u = -2 * sum([integral(val)[0] for val in a]) # Unit Harmony (penalizes unbounded growth of state vector)
    return H_c + H_u

def analytic_plot(prompt, steps, time=1):
    # Plot the analytic solution to a differential equation, given weight matrix and starting state
    trange = np.arange(0, time, dt)
    sim_vals = np.zeros(shape=(len(patterns), time/dt))  
    coefficients = np.linalg.solve(eigvecs, prompt)
    
    for t in trange:
        solution = normalize(np.dot(eigvecs, coefficients * np.exp(eigvals*t))).real
        sim_vals[:,np.where(trange==t)[0][0]] = np.dot(stack, solution).real
    for i in range(sim_vals.shape[0]):
        plt.plot(trange, sim_vals[i,:])
        plt.legend(patterns.keys(), bbox_to_anchor=(1.5, 1.3))
    plt.title('Analytic Solution')
    plt.show()

# %% [markdown]
# Next, we initialize the HRRs, weights, and starting state of the hopfield network:

# %%
# Generate 5 random HRRs and pick one to test. 
patterns = ['P1','P2','P3','P4','P5']
patterns = {p: normalize(np.random.randn(D)) for p in patterns}
test_pattern = patterns['P2']

# Generate a bias vector to shift the tuning curves of the tanh neurons.
bias = normalize(np.random.randn(D))

# Create an initial state vector and copy it for solving a linear system analytically
a = disturb(test_pattern, 0.2)
a_linear = copy.copy(a)

# Build a weight matrix from the pattern HRRs
weights = np.zeros((D,D))
for p in patterns:
    weights += np.outer(patterns[p], patterns[p])

# Matrix for computing similarity of state to known patterns
stack = np.vstack(tuple(patterns.values()))

# %% [markdown]
# In preparation for finding the analytic solution, we perform an eigenvalue decomposition on the weight matrix. Note that the eigenvalue decomposition tends to generate extremely small numbers in place of eigenvalues of zero. As such, we ignore values with an absolute values of less than 0.001. The rank of an NxN matrix of is equal to the number of non-zero eigenvalues (since N-r is equal to dimensionality of the matrix's nullspace, which is comprised of eigenvectors with an eigenvalue of 0). To examine the behavior of a system defined by this weight matrix, we convert a hypothetical input into a linear combination of the eigenvectors of the matrix and then solve for the state of the system after an arbitrary amount of time by determining coefficents on the eigenvectors that give the system state at this time.

# %%
eigvals, eigvecs = np.linalg.eig(weights)

# Test the conversion of an input into a linear combination of eigenvectors
coefficients = np.linalg.solve(eigvecs, test_pattern)

# This should print 'Passed!' if the combination of eigenvectors is equal to the test pattern.
print 'Eigenbasis Test:'
if np.allclose(np.dot(eigvecs,coefficients), test_pattern) == True:
    print 'Passed!'
# Out:
# Eigenbasis Test:
# Passed!

# %% [markdown]
# Now we want to see what the system does over time. With a matrix difference equation, we just multiply the input vector by the matrix to the power of t (time) to get the state of the system at that time. However, in the Hopfield network we will be solving differential equations. If we set the difference $A_d = A_t+I$ where $A_t$ is the matrix for the differential equation, we get a difference equation that behaves identically in the limit to the corresponding differential equation. That is:
#
# $x_{t+1}-x_t = A_t x_t $
#
# $x_{t+1} = A_t x_t + x_t = (A_t + I)x_t$

# %%
# Find the analytic solution 
eigvals, eigvecs = np.linalg.eig(weights+np.eye(D))
coefficients = np.linalg.solve(eigvecs,  test_pattern)

solution = np.dot(eigvecs, coefficients * np.exp(eigvals*t))

# Note that the eigvals > 1 cause the solution to blow up. 
# Norm of vector increases very rapidly. 
print ''
print 'Norm of state after '+str(t)+'s time'
print np.linalg.norm(solution)
# Out:
# Norm of state after 5s time
# 44383.5588835

# %% [markdown]
# We can now run the hopfield network to observe its behavior over the same time interval and compare the results between the analytic solution and the hopfield solution.

# %%
# Number of time steps to run the network.
steps = int(t/dt)

# Initialize arrays for collecting similarity and harmony (i.e. energy) values
sim_vals = np.zeros((len(patterns), steps))
harmony = np.zeros(steps)

# Run the network, updating the state vector at each time step in accordance with a diff. eq. in the update function. 
for s in range(steps):
    a = update(a, weights)
    H = harmony_eval(a, weights)
    # Collect data for plotting.
    harmony[s] = H
    sim_vals[:,s] = np.dot(stack, normalize(a))

# Plot the state trajectory of the hopfield network over time.
for i in range(sim_vals.shape[0]):
    plt.plot(range(steps), sim_vals[i,:])
plt.plot(range(steps), harmony/10) # scale harmony for visualization purposes.
plt.title('Hopfield Network')
plt.legend(patterns.keys()+['Harmony'], bbox_to_anchor=(1.5, 1.3))
plt.show()

analytic_plot(a_linear, steps, time=t)

# %%
print 'Cosine of angle between final state and attractor state'
print 'Hopfield: ', np.dot(normalize(a), test_pattern)
print 'Analytic: ', np.dot(normalize(solution), test_pattern).real

print 'Normalized dot product of the two solution states:'
print np.dot(normalize(solution), normalize(a)).real
# Out:
# Cosine of angle between final state and attractor state
# Hopfield:  0.444792893611
# Analytic:  0.805968300691
# Normalized dot product of the two solution states:
# 0.852989260668

# %% [markdown]
# The behavior of the two systems is qualitatively somewhat similar (i.e. with respect to the ordering of similarity values). The hopfield network stabilizes much more quickly, though, due to the large value of the scaling factor, k, in its update rule. If we increase the time used to calculate the analytic solution, we can observe that it converges on roughly the same state as the hopfield network.

# %%
# Run the network again, comparing instead to the analytic solution at a greater time.
a = a_linear
a_linear = copy.copy(a)

for s in range(steps):
    a = update(a, weights)
    H = harmony_eval(a, weights)
    # Collect data for plotting.
    harmony[s] = H
    sim_vals[:,s] = np.dot(stack, normalize(a))
    
for i in range(sim_vals.shape[0]):
    plt.plot(range(steps), sim_vals[i,:])
plt.plot(range(steps), harmony/10) 
plt.title('Hopfield Network')
plt.legend(patterns.keys()+['Harmony'], bbox_to_anchor=(1.5, 1.3))
plt.show()

analytic_plot(a_linear, steps, time=30) # increased time

# %% [markdown]
# One possible explanation for this lack of difference between the hopfield net and the linear system is that tanh behaves linearly close to 0, which is where most of the elements in a high-dimensional HRR are located. So, if the elements of the state vector are all quite small, then the hopfield network will behave like a linear system.
